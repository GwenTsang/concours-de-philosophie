# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os

src = '/content/drive/MyDrive/main'
dst = '/content/to_crop'

if os.path.exists(dst):
    shutil.rmtree(dst)

shutil.copytree(src, dst)
# Out:
# '/content/to_crop'

# %%
#@title Retirer l'encas de numérotation pour toutes les images dans /to_crop

from PIL import Image, ImageDraw
import os

# --- Configuration ---
root_folder = "/content/to_crop"  # The main folder containing subfolders with images
coords = (2175, 3305, 2413, 3406) # Coordinates for the rectangle (x0, y0, x1, y1)
fill_color = "white"             # Fill color for the rectangle
# --- End Configuration ---

# Check if the root folder exists
if not os.path.isdir(root_folder):
    print(f"Error: Root directory not found at '{root_folder}'")
else:
    print(f"Starting processing in folder: '{root_folder}'")
    processed_count = 0
    error_count = 0

    # Walk through the directory tree
    for dirpath, dirnames, filenames in os.walk(root_folder):
        print(f"Scanning directory: {dirpath}")
        for filename in filenames:
            # Check if the file is a PNG image (case-insensitive check)
            if filename.lower().endswith(".png"):
                image_path = os.path.join(dirpath, filename)
                print(f"  Processing image: {image_path}...")

                try:
                    # Open the image using a 'with' statement for proper resource handling
                    with Image.open(image_path) as img:
                        # Ensure the image is in a mode that supports drawing (e.g., RGB, RGBA)
                        # If it's indexed (like 'P'), convert it.
                        if img.mode == 'P':
                           img = img.convert('RGBA')
                        elif img.mode == 'L': # Grayscale
                           img = img.convert('RGB')
                        elif img.mode not in ('RGB', 'RGBA'):
                           print(f"    Warning: Image mode '{img.mode}' might not be ideal for drawing. Converting to RGBA.")
                           img = img.convert('RGBA')


                        # Create a drawing object
                        draw = ImageDraw.Draw(img)

                        # Draw the white rectangle
                        draw.rectangle(coords, fill=fill_color, outline=None)

                        # Save the modified image, overwriting the original
                        # Pillow typically preserves the original format if possible when saving
                        # to the same path without specifying a format.
                        img.save(image_path, format='PNG') # Explicitly specify PNG for safety

                    print(f"    Successfully modified and saved: '{image_path}'")
                    processed_count += 1

                except FileNotFoundError:
                     print(f"    Error: File disappeared during processing: '{image_path}'")
                     error_count += 1
                except Exception as e:
                    print(f"    An error occurred while processing '{image_path}': {e}")
                    error_count += 1
            # else:
            #    print(f"  Skipping non-PNG file: {filename}") # Optional: uncomment to see skipped files

    print("\n--- Processing Complete ---")
    print(f"Total images processed successfully: {processed_count}")
    print(f"Total errors encountered: {error_count}")
# Out:
# Starting processing in folder: '/content/to_crop'
# Scanning directory: /content/to_crop
# Scanning directory: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_14.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_14.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_11.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_09.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_16.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_16.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_04.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_12.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_07.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_13.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_13.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_15.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_15.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_05.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_10.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_03.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_02.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_06.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_08.png'
#   Processing image: /content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_12.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)/page_01.png'
# Scanning directory: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_11.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_09.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_04.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_12.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_07.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_05.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_10.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_03.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_02.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_06.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_08.png'
#   Processing image: /content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_14.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_14.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_12.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_13.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_13.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_15.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_15.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)/page_01.png'
# Scanning directory: /content/to_crop/Lusage des principes (note 13)
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_11.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_09.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_04.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_12.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_07.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_05.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_10.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_03.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_02.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_06.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_08.png'
#   Processing image: /content/to_crop/Lusage des principes (note 13)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Lusage des principes (note 13)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_14.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_14.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_18.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_18.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_16.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_16.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_12.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_13.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_13.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_15.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_15.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_17.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_17.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)/page_01.png'
# Scanning directory: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_2.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_2.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_4.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_4.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_8.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_8.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_7.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_7.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_1.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_1.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_3.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_3.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_6.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_6.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_5.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_5.png'
# Scanning directory: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_12.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_12.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)/page_01.png'
# Scanning directory: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_14.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_14.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_11.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_09.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_16.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_16.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_04.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_12.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_07.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_13.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_13.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_15.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_15.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_05.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_10.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_03.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_02.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_06.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_08.png'
#   Processing image: /content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Hobbes (note 18)
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Hobbes (note 18)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Hobbes (note 18)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_09.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_04.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_07.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_05.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_10.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_03.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_02.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_06.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_08.png'
#   Processing image: /content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_14.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_14.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_16.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_16.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_12.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_13.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_13.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_15.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_15.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)/page_01.png'
# Scanning directory: /content/to_crop/Commentaire de Leibniz (note _ 17)
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_19.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_19.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_14.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_14.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_18.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_18.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_11.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_09.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_16.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_16.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_04.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_12.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_20.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_20.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_07.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_13.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_13.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_15.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_15.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_05.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_10.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_17.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_17.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_03.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_02.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_06.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_08.png'
#   Processing image: /content/to_crop/Commentaire de Leibniz (note _ 17)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Commentaire de Leibniz (note _ 17)/page_01.png'
# Scanning directory: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_14.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_14.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_11.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_09.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_16.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_16.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_04.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_12.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_12.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_07.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_13.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_13.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_15.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_15.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_05.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_10.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_03.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_02.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_06.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_08.png'
#   Processing image: /content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)/page_01.png'
# Scanning directory: /content/to_crop/Etre sensible (note 13)
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_09.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_04.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_07.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_05.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_10.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_03.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_02.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_06.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_08.png'
#   Processing image: /content/to_crop/Etre sensible (note 13)/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Etre sensible (note 13)/page_01.png'
#
# --- Processing Complete ---
# Total images processed successfully: 269
# Total errors encountered: 0

# %%
import shutil
import os

src = '/content/drive/MyDrive/Le vrai et le réel (AGREG 2020 - note : 13,5)'
dst = '/content/model'

if os.path.exists(dst):
    shutil.rmtree(dst)

shutil.copytree(src, dst)
# Out:
# '/content/model'

# %%
import shutil
import os

src = '/content/drive/MyDrive/main'
dst = '/content/to_crop'

if os.path.exists(dst):
    shutil.rmtree(dst)

shutil.copytree(src, dst)
# Out:
# '/content/to_crop'

# %%
#@title Découpage du header grâce à un modèle

import os
from PIL import Image
import sys # For potentially exiting on critical errors
import re # Import regular expressions module

print("--- Image Cropping Script Started (v3 - Handling Number Padding) ---")

# --- Configuration ---
model_folder = "/content/model"
to_crop_base_folder = "/content/to_crop"
# --- End Configuration ---

# --- Helper Function to Extract Page Number ---
def extract_page_number(filename):
    """
    Extracts the integer page number from filenames like:
    page_001.png, Page_1.PNG, document_05.png etc.
    Returns the integer number or None if no number is found.
    """
    # Regex to find one or more digits (\d+) potentially preceded by common separators (_ or - or space)
    # It looks for digits occurring before the .png extension (case-insensitive)
    match = re.search(r'[_ \-]?(?P<number>\d+)\.(png|jpeg|jpg|tif|tiff)$', filename, re.IGNORECASE)
    if match:
        try:
            return int(match.group('number'))
        except (ValueError, TypeError):
            return None # Should not happen with \d+ but good practice
    else:
        # Fallback: Maybe just digits before extension?
        match = re.search(r'(?P<number>\d+)\.(png|jpeg|jpg|tif|tiff)$', filename, re.IGNORECASE)
        if match:
            try:
                return int(match.group('number'))
            except (ValueError, TypeError):
                return None
    print(f"    Debug: Could not extract page number from filename: '{filename}'")
    return None # No number found

# --- Input Validation ---
if not os.path.isdir(model_folder):
    print(f"Error: Template folder not found: {model_folder}")
    sys.exit(1)

if not os.path.isdir(to_crop_base_folder):
    print(f"Error: Base folder to crop not found: {to_crop_base_folder}")
    sys.exit(1)

# --- Step 1: Determine Crop Thresholds using Page Numbers ---
print(f"\n--- Step 1: Determining Crop Thresholds from '{model_folder}' (Matching by Page Number) ---")
# Store thresholds keyed by page number (integer) instead of filename string
crop_thresholds_by_num = {} # Dictionary: { 1: y_threshold, 2: y_threshold, ... }

# List PNG files in the model folder
try:
    model_filenames = [f for f in os.listdir(model_folder) if re.search(r'\.(png|jpeg|jpg|tif|tiff)$', f, re.IGNORECASE)]
    if not model_filenames:
         print(f"Warning: No image files (png, jpg, etc.) found in the template folder: {model_folder}")
except OSError as e:
     print(f"Error listing files in template folder {model_folder}: {e}")
     sys.exit(1)

# Find subfolders to sample original heights
try:
    subfolders = [os.path.join(to_crop_base_folder, d) for d in os.listdir(to_crop_base_folder) if os.path.isdir(os.path.join(to_crop_base_folder, d))]
    if not subfolders and model_filenames:
         print(f"Warning: No subfolders found within '{to_crop_base_folder}'. Cannot determine original heights.")
except OSError as e:
     print(f"Error listing subfolders in {to_crop_base_folder}: {e}")
     sys.exit(1)

# Iterate through each template file
for template_filename in sorted(model_filenames): # Sort for consistent processing if needed
    template_path = os.path.join(model_folder, template_filename)
    template_page_num = extract_page_number(template_filename)

    if template_page_num is None:
        print(f"  Warning: Could not extract page number from template '{template_filename}'. Skipping.")
        continue

    # Avoid recalculating if already found for this page number (e.g., if multiple templates exist for same page)
    if template_page_num in crop_thresholds_by_num:
        continue

    original_height = None
    template_height = None
    original_image_path_found = None

    try:
        # Get template height
        with Image.open(template_path) as model_img:
            template_height = model_img.height

        # Find *one* corresponding image in any subfolder based on PAGE NUMBER
        if subfolders:
            found_match_in_subfolders = False
            for subfolder in subfolders:
                try:
                    for target_filename in os.listdir(subfolder):
                         target_path = os.path.join(subfolder, target_filename)
                         if os.path.isfile(target_path): # Ensure it's a file
                            target_page_num = extract_page_number(target_filename)
                            # Check if the extracted number matches the template's number
                            if target_page_num == template_page_num:
                                try:
                                    with Image.open(target_path) as uncropped_img:
                                        original_height = uncropped_img.height
                                        original_image_path_found = target_path
                                        found_match_in_subfolders = True
                                        # print(f"    Debug: Found match for page {template_page_num}: '{target_path}' (H={original_height})")
                                        break # Found representative original for this page number
                                except Exception as img_err:
                                     print(f"  Warning: Could not open sample image '{target_path}' to determine height for page {template_page_num}. Error: {img_err}")
                                     # Continue searching in the same subfolder or next one
                    if found_match_in_subfolders:
                         break # Stop searching subfolders once a match is found and opened
                except OSError as list_err:
                     print(f"  Warning: Could not list files in subfolder '{subfolder}'. Skipping it for threshold calculation. Error: {list_err}")
            # Check if we found a sample after searching all subfolders
            if not found_match_in_subfolders:
                 print(f"  Warning: Could not find any corresponding image for page number {template_page_num} (from '{template_filename}') in subfolders of '{to_crop_base_folder}'. Cannot determine threshold.")


        # Calculate and store the threshold if heights were found
        if template_height is not None and original_height is not None:
            y_threshold = original_height - template_height
            if y_threshold < 0:
                 print(f"  Warning: Calculated negative threshold ({y_threshold}) for page {template_page_num} ('{template_filename}'). "
                       f"Original height ({original_height} from {original_image_path_found}) might be smaller than template height ({template_height}). "
                       f"Setting threshold to 0.")
                 y_threshold = 0

            crop_thresholds_by_num[template_page_num] = y_threshold
            print(f"  Threshold for Page {template_page_num}: Remove y={y_threshold} pixels from top (Based on Original H: {original_height}, Template H: {template_height})")

        elif template_height is None:
             print(f"  Error: Could not read template image '{template_path}'. Skipping threshold calculation.")
        # No 'else' needed, warning about not finding match covers other cases

    except FileNotFoundError:
        print(f"  Error: Template file not found '{template_path}'. Skipping.")
    except Exception as e:
        print(f"  Error processing template '{template_path}': {e}. Skipping threshold calculation.")

if not crop_thresholds_by_num:
     print("\nWarning: No crop thresholds were determined. No images will be cropped.")

# --- Step 2: Apply Cropping using Page Numbers ---
print(f"\n--- Step 2: Applying Cropping to Images in '{to_crop_base_folder}' Subfolders (Matching by Page Number) ---")

processed_count = 0
skipped_count = 0
error_count = 0

# Iterate through each subfolder
for subfolder_name in os.listdir(to_crop_base_folder):
    subfolder_path = os.path.join(to_crop_base_folder, subfolder_name)

    if os.path.isdir(subfolder_path):
        print(f"\nProcessing folder: '{subfolder_path}'")
        try:
            # Iterate through each file in the current subfolder
            for filename in sorted(os.listdir(subfolder_path)): # Sort for predictable order
                target_image_path = os.path.join(subfolder_path, filename)
                if not os.path.isfile(target_image_path): # Skip directories
                    continue

                # Extract page number from the target filename
                target_page_num = extract_page_number(filename)

                if target_page_num is not None:
                    # Check if we have a calculated threshold for this PAGE NUMBER
                    if target_page_num in crop_thresholds_by_num:
                        calculated_y_threshold = crop_thresholds_by_num[target_page_num]
                        current_y_to_crop = calculated_y_threshold

                        try:
                            with Image.open(target_image_path) as img:
                                width, height = img.size

                                # Safety Check against image height
                                if calculated_y_threshold >= height:
                                     print(f"  Warning: Calculated header height ({calculated_y_threshold}px) for page {target_page_num} is >= actual image height ({height}px) for '{filename}'. Setting crop amount to 0.")
                                     current_y_to_crop = 0
                                elif calculated_y_threshold < 0:
                                      print(f"  Warning: Negative crop threshold ({calculated_y_threshold}) encountered for page {target_page_num} ('{filename}'). Setting crop amount to 0.")
                                      current_y_to_crop = 0

                                # Define crop box
                                crop_box = (0, current_y_to_crop, width, height)

                                # Perform crop only if necessary and valid
                                if current_y_to_crop >= height:
                                     print(f"  Skipping crop for '{filename}' as adjusted crop area is invalid (Crop top {current_y_to_crop} >= Height {height}).")
                                     skipped_count +=1
                                elif current_y_to_crop <= 0:
                                     # Log skipping if threshold was 0 or adjusted to 0
                                     reason = "calculated threshold was 0" if calculated_y_threshold <= 0 else "height constraint"
                                     print(f"  Skipping crop for '{filename}' as {reason}. Image not modified.")
                                     skipped_count += 1
                                else:
                                    # Proceed with cropping
                                    cropped_img = img.crop(crop_box)
                                    save_kwargs = {}
                                    if 'icc_profile' in img.info: save_kwargs['icc_profile'] = img.info['icc_profile']
                                    if 'dpi' in img.info: save_kwargs['dpi'] = img.info['dpi']
                                    cropped_img.save(target_image_path, **save_kwargs)
                                    print(f"  Cropped and overwritten: '{filename}' (Removed {current_y_to_crop}px from top)")
                                    processed_count += 1

                        except FileNotFoundError:
                            print(f"  Error: Image file not found during processing: '{target_image_path}'. Skipping.")
                            error_count += 1
                        except Exception as e:
                            print(f"  Error processing image '{target_image_path}': {e}. Skipping.")
                            error_count += 1
                    else:
                        # Page number extracted, but no threshold was calculated for it (e.g., template missing)
                        print(f"  Skipping: '{filename}' (No threshold found for page number {target_page_num})")
                        skipped_count += 1
                else:
                    # Could not extract a page number from this filename
                    print(f"  Skipping: '{filename}' (Could not determine page number)")
                    skipped_count += 1
        except OSError as e:
             print(f"Error accessing files within subfolder '{subfolder_path}': {e}. Skipping this folder.")

print("\n--- Cropping Script Finished ---")
print(f"Summary:")
print(f"  Successfully cropped and overwritten: {processed_count} images")
print(f"  Skipped (no threshold, height constraint, 0 threshold, or unparsable): {skipped_count} images")
print(f"  Errors encountered during processing: {error_count} images/folders")
print("----------------------------------")
# Out:
# --- Image Cropping Script Started (v3 - Handling Number Padding) ---
#
# --- Step 1: Determining Crop Thresholds from '/content/model' (Matching by Page Number) ---
#   Threshold for Page 1: Remove y=910 pixels from top (Based on Original H: 3508, Template H: 2598)
#   Threshold for Page 2: Remove y=508 pixels from top (Based on Original H: 3508, Template H: 3000)
#   Threshold for Page 3: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 4: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 5: Remove y=929 pixels from top (Based on Original H: 3508, Template H: 2579)
#   Threshold for Page 6: Remove y=509 pixels from top (Based on Original H: 3508, Template H: 2999)
#   Threshold for Page 7: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 8: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 9: Remove y=898 pixels from top (Based on Original H: 3508, Template H: 2610)
#   Threshold for Page 10: Remove y=508 pixels from top (Based on Original H: 3508, Template H: 3000)
#   Threshold for Page 11: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 12: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 13: Remove y=905 pixels from top (Based on Original H: 3508, Template H: 2603)
#   Threshold for Page 14: Remove y=509 pixels from top (Based on Original H: 3508, Template H: 2999)
#   Threshold for Page 15: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 16: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 17: Remove y=815 pixels from top (Based on Original H: 3508, Template H: 2693)
#   Threshold for Page 18: Remove y=508 pixels from top (Based on Original H: 3508, Template H: 3000)
#   Threshold for Page 19: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Threshold for Page 20: Remove y=0 pixels from top (Based on Original H: 3508, Template H: 3508)
#   Warning: Could not find any corresponding image for page number 21 (from 'page_21.png') in subfolders of '/content/to_crop'. Cannot determine threshold.
#   Warning: Could not find any corresponding image for page number 22 (from 'page_22.png') in subfolders of '/content/to_crop'. Cannot determine threshold.
#   Warning: Could not find any corresponding image for page number 23 (from 'page_23.png') in subfolders of '/content/to_crop'. Cannot determine threshold.
#   Warning: Could not find any corresponding image for page number 24 (from 'page_24.png') in subfolders of '/content/to_crop'. Cannot determine threshold.
#   Warning: Could not find any corresponding image for page number 25 (from 'page_25.png') in subfolders of '/content/to_crop'. Cannot determine threshold.
#
# --- Step 2: Applying Cropping to Images in '/content/to_crop' Subfolders (Matching by Page Number) ---
#
# Processing folder: '/content/to_crop/Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_13.png' (Removed 905px from top)
#   Cropped and overwritten: 'page_14.png' (Removed 509px from top)
#   Skipping crop for 'page_15.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_16.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note 12)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Diderot (CAPES - note _ 14)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#
# Processing folder: '/content/to_crop/Les maîtres de vérité (CAPES 2022 - note : 11)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 16)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_13.png' (Removed 905px from top)
#   Cropped and overwritten: 'page_14.png' (Removed 509px from top)
#   Skipping crop for 'page_15.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 12)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Lusage des principes (note 13)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note _ 12)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_13.png' (Removed 905px from top)
#   Cropped and overwritten: 'page_14.png' (Removed 509px from top)
#   Skipping crop for 'page_15.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_16.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_17.png' (Removed 815px from top)
#   Cropped and overwritten: 'page_18.png' (Removed 508px from top)
#
# Processing folder: '/content/to_crop/La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)'
#   Cropped and overwritten: 'page_1.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_2.png' (Removed 508px from top)
#   Skipping crop for 'page_3.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_4.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_5.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_6.png' (Removed 509px from top)
#   Skipping crop for 'page_7.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_8.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Diderot (AGREG ext. - note _ 10)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Leibniz (AGREG interne 2022 - note _ 14)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_13.png' (Removed 905px from top)
#   Cropped and overwritten: 'page_14.png' (Removed 509px from top)
#   Skipping crop for 'page_15.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_16.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 10)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Hobbes (note 18)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#
# Processing folder: '/content/to_crop/Commentaire de Mill (AGREG 2022 - note _ 19)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_13.png' (Removed 905px from top)
#   Cropped and overwritten: 'page_14.png' (Removed 509px from top)
#   Skipping crop for 'page_15.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_16.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Foucault - Naissance de la clinique (AGREG interne 2021 - note 13)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Commentaire de Didero (CAPES 2019 - note _ 19)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#
# Processing folder: '/content/to_crop/Commentaire de Leibniz (note _ 17)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_13.png' (Removed 905px from top)
#   Cropped and overwritten: 'page_14.png' (Removed 509px from top)
#   Skipping crop for 'page_15.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_16.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_17.png' (Removed 815px from top)
#   Cropped and overwritten: 'page_18.png' (Removed 508px from top)
#   Skipping crop for 'page_19.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_20.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Les maitres de vérité (CAPES 2022 - note : 11)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#   Skipping crop for 'page_11.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_12.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_13.png' (Removed 905px from top)
#   Cropped and overwritten: 'page_14.png' (Removed 509px from top)
#   Skipping crop for 'page_15.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_16.png' as calculated threshold was 0. Image not modified.
#
# Processing folder: '/content/to_crop/Etre sensible (note 13)'
#   Cropped and overwritten: 'page_01.png' (Removed 910px from top)
#   Cropped and overwritten: 'page_02.png' (Removed 508px from top)
#   Skipping crop for 'page_03.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_04.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_05.png' (Removed 929px from top)
#   Cropped and overwritten: 'page_06.png' (Removed 509px from top)
#   Skipping crop for 'page_07.png' as calculated threshold was 0. Image not modified.
#   Skipping crop for 'page_08.png' as calculated threshold was 0. Image not modified.
#   Cropped and overwritten: 'page_09.png' (Removed 898px from top)
#   Cropped and overwritten: 'page_10.png' (Removed 508px from top)
#
# --- Cropping Script Finished ---
# Summary:
#   Successfully cropped and overwritten: 142 images
#   Skipped (no threshold, height constraint, 0 threshold, or unparsable): 127 images
#   Errors encountered during processing: 0 images/folders
# ----------------------------------

# %%
import os
import numpy as np
from PIL import Image, ImageStat
import ipywidgets as widgets
from IPython.display import display, clear_output, Image as IPImage
import io
import time # To prevent potential race conditions with display updates

# --- Configuration ---
MAIN_FOLDER_PATH = "/content/to_crop"  # <<< CHANGE THIS if your main folder is elsewhere
CONTRAST_THRESHOLD = 25.0  # <<< ADJUST AS NEEDED (lower = closer to pure white/black)
DISPLAY_WIDTH = 600 # Max width to display the image in pixels

# --- Globals for Interaction State ---
candidate_images = []
current_index = -1
output_area = widgets.Output() # Area to display images and buttons

# --- Helper Functions ---

def calculate_contrast(image_path):
    """
    Calculates a contrast metric for an image.
    Uses standard deviation of grayscale pixel values.
    Returns None if the file is not a valid image.
    """
    try:
        with Image.open(image_path) as img:
            # Convert to grayscale for simpler analysis
            grayscale_img = img.convert('L')
            # Calculate standard deviation of pixel values
            stat = ImageStat.Stat(grayscale_img)
            return stat.stddev[0] # stddev is a list with one element for grayscale
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return None

def find_low_contrast_images(root_folder, threshold):
    """
    Scans the folder structure and finds images below the contrast threshold.
    """
    low_contrast_files = []
    print(f"Scanning folder: {root_folder} ...")
    if not os.path.isdir(root_folder):
        print(f"Error: Folder not found: {root_folder}")
        return []

    for subdir, _, files in os.walk(root_folder):
        # Sort files to process pages in order (e.g., Page_001, Page_002)
        # This helps if you want to stop early but keep pages sequential
        files.sort()
        for filename in files:
            if filename.lower().endswith('.png'):
                image_path = os.path.join(subdir, filename)
                contrast = calculate_contrast(image_path)
                if contrast is not None and contrast < threshold:
                    low_contrast_files.append(image_path)
                    print(f"  - Flagged: {os.path.relpath(image_path, root_folder)} (Contrast: {contrast:.2f})")

    print(f"\nFound {len(low_contrast_files)} potential blank pages to review.")
    return low_contrast_files

# --- Button Click Handlers ---

def on_keep_clicked(b):
    """Handles the Keep button click."""
    global current_index
    image_path = candidate_images[current_index]
    with output_area:
        clear_output(wait=True)
        print(f"Keeping: {os.path.relpath(image_path, MAIN_FOLDER_PATH)}")
        # Add a small delay to ensure the message is seen before the next image
        time.sleep(0.5)
        show_next_image()

def on_delete_clicked(b):
    """Handles the Delete button click."""
    global current_index
    image_path = candidate_images[current_index]
    try:
        os.remove(image_path)
        with output_area:
            clear_output(wait=True)
            print(f"Deleted: {os.path.relpath(image_path, MAIN_FOLDER_PATH)}")
            # Add a small delay
            time.sleep(0.5)
            show_next_image()
    except Exception as e:
         with output_area:
            clear_output(wait=True)
            print(f"Error deleting {os.path.relpath(image_path, MAIN_FOLDER_PATH)}: {e}")
            # Add a small delay
            time.sleep(1.0)
            # Still proceed to the next image even if deletion failed
            show_next_image()


# --- Display Logic ---

def show_next_image():
    """Displays the next candidate image or finishes."""
    global current_index
    current_index += 1

    with output_area: # Ensure output happens within the designated area
        if current_index < len(candidate_images):
            image_path = candidate_images[current_index]
            print(f"\nReviewing image {current_index + 1}/{len(candidate_images)}:")
            print(f"File: {os.path.relpath(image_path, MAIN_FOLDER_PATH)}")

            # Display Image using IPython.display.Image for better handling
            try:
                display(IPImage(filename=image_path, width=DISPLAY_WIDTH))
            except Exception as e:
                print(f"Error displaying image {image_path}: {e}")


            # Create Buttons
            keep_button = widgets.Button(description="Keep", button_style="success", icon="check")
            delete_button = widgets.Button(description="Delete", button_style="danger", icon="trash")

            # Assign click handlers
            keep_button.on_click(on_keep_clicked)
            delete_button.on_click(on_delete_clicked)

            # Display Buttons horizontally
            buttons = widgets.HBox([keep_button, delete_button])
            display(buttons)

        else:
            print("\n--- Review Complete ---")
            if len(candidate_images) == 0:
                print("No low-contrast images were found to review.")
            else:
                 print(f"Finished reviewing {len(candidate_images)} images.")


# --- Main Execution ---

# 1. Find candidates first
candidate_images = find_low_contrast_images(MAIN_FOLDER_PATH, CONTRAST_THRESHOLD)

# 2. Setup the display area and start the interactive review
display(output_area) # Display the output area widget FIRST
show_next_image() # Start the review process by showing the first image (if any)
# Out:
# Scanning folder: /content/to_crop ...
#   - Flagged: Commentaire Locke, Essay, II, 21 (AGREG ext. 2019 - note _ 16)/page_16.png (Contrast: 17.29)
#   - Flagged: Commentaire de Mill (AGREG 2022 - note 12)/page_12.png (Contrast: 23.10)
#   - Flagged: Commentaire de Diderot (CAPES - note _ 14)/page_10.png (Contrast: 17.41)
#   - Flagged: Les maîtres de vérité (CAPES 2022 - note : 11)/page_10.png (Contrast: 19.89)
#   - Flagged: Les maîtres de vérité (CAPES 2022 - note : 11)/page_11.png (Contrast: 11.42)
#   - Flagged: Les maîtres de vérité (CAPES 2022 - note : 11)/page_12.png (Contrast: 12.23)
#   - Flagged: La paix est-elle le plus grand des biens ? (CAPES 2020 - note : 14,5)/page_8.png (Contrast: 14.19)
#   - Flagged: La paix est-elle le plus grand des biens (CAPES 2020 - note : 15)/page_16.png (Contrast: 14.97)
#   - Flagged: Commentaire du Leviathan (AGREG ext. 2022 - note _ 13)/page_10.png (Contrast: 13.86)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_01.png (Contrast: 22.03)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_05.png (Contrast: 19.09)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_06.png (Contrast: 24.27)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_07.png (Contrast: 24.49)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_08.png (Contrast: 22.01)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_09.png (Contrast: 23.97)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_15.png (Contrast: 22.88)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_16.png (Contrast: 24.43)
#   - Flagged: Commentaire de Leibniz (note _ 17)/page_20.png (Contrast: 23.56)
#   - Flagged: Les maitres de vérité (CAPES 2022 - note : 11)/page_15.png (Contrast: 19.68)
#   - Flagged: Les maitres de vérité (CAPES 2022 - note : 11)/page_16.png (Contrast: 16.71)
#
# Found 20 potential blank pages to review.
# Output()
