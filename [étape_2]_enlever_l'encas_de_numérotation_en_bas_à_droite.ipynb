# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os

src = '/content/drive/MyDrive/2025'
dst = '/content/to_crop'

if os.path.exists(dst):
    shutil.rmtree(dst)

shutil.copytree(src, dst)
# Out:
# '/content/to_crop'

# %%
#@title Retirer le 1er encas de numérotation pour toutes les images dans /to_crop

from PIL import Image, ImageDraw
import os

# --- Configuration ---
root_folder = "/content/to_crop"  # The main folder containing subfolders with images
coords = (2175, 3305, 2413, 3406) # Coordinates for the rectangle (x0, y0, x1, y1)
fill_color = "white"             # Fill color for the rectangle
# --- End Configuration ---

# Check if the root folder exists
if not os.path.isdir(root_folder):
    print(f"Error: Root directory not found at '{root_folder}'")
else:
    print(f"Starting processing in folder: '{root_folder}'")
    processed_count = 0
    error_count = 0

    # Walk through the directory tree
    for dirpath, dirnames, filenames in os.walk(root_folder):
        print(f"Scanning directory: {dirpath}")
        for filename in filenames:
            # Check if the file is a PNG image (case-insensitive check)
            if filename.lower().endswith(".png"):
                image_path = os.path.join(dirpath, filename)
                print(f"  Processing image: {image_path}...")

                try:
                    # Open the image using a 'with' statement for proper resource handling
                    with Image.open(image_path) as img:
                        # Ensure the image is in a mode that supports drawing (e.g., RGB, RGBA)
                        # If it's indexed (like 'P'), convert it.
                        if img.mode == 'P':
                           img = img.convert('RGBA')
                        elif img.mode == 'L': # Grayscale
                           img = img.convert('RGB')
                        elif img.mode not in ('RGB', 'RGBA'):
                           print(f"    Warning: Image mode '{img.mode}' might not be ideal for drawing. Converting to RGBA.")
                           img = img.convert('RGBA')


                        # Create a drawing object
                        draw = ImageDraw.Draw(img)

                        # Draw the white rectangle
                        draw.rectangle(coords, fill=fill_color, outline=None)

                        # Save the modified image, overwriting the original
                        # Pillow typically preserves the original format if possible when saving
                        # to the same path without specifying a format.
                        img.save(image_path, format='PNG') # Explicitly specify PNG for safety

                    print(f"    Successfully modified and saved: '{image_path}'")
                    processed_count += 1

                except FileNotFoundError:
                     print(f"    Error: File disappeared during processing: '{image_path}'")
                     error_count += 1
                except Exception as e:
                    print(f"    An error occurred while processing '{image_path}': {e}")
                    error_count += 1
            # else:
            #    print(f"  Skipping non-PNG file: {filename}") # Optional: uncomment to see skipped files

    print("\n--- Processing Complete ---")
    print(f"Total images processed successfully: {processed_count}")
    print(f"Total errors encountered: {error_count}")
# Out:
# Starting processing in folder: '/content/to_crop'
# Scanning directory: /content/to_crop
# Scanning directory: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_08.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_08.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_12.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_12.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_05.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_05.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_03.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_03.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_04.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_04.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_09.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_09.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_01.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_01.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_02.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_02.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_07.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_07.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_06.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_06.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_10.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_10.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_11.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_11.png'
# Scanning directory: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_08.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_08.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_05.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_05.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_03.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_03.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_04.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_04.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_09.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_09.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_01.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_01.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_02.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_02.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_07.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_07.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_06.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_06.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_10.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_10.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_11.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_11.png'
# Scanning directory: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_08.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_08.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_12.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_12.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_05.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_05.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_03.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_03.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_04.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_04.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_09.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_09.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_01.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_01.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_02.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_02.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_07.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_07.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_06.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_06.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_10.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_10.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_11.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_11.png'
# Scanning directory: /content/to_crop/Copie CAPES 2025 - Perfection
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_08.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_05.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_03.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_04.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_09.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_01.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_02.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_07.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_06.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_10.png'
# Scanning directory: /content/to_crop/Copie agreg 2025 - Savoir désirable
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_08.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_05.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_03.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_04.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_09.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_01.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_02.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_07.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_06.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_10.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_11.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_11.png'
# Scanning directory: /content/to_crop/Copie agreg 2025 - Avoir de la chance
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_08.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_08.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_05.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_03.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_03.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_04.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_04.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_09.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_01.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_02.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_02.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_07.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_07.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_06.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_06.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_10.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_10.png'
#
# --- Processing Complete ---
# Total images processed successfully: 66
# Total errors encountered: 0

# %%
#@title Deuxième encas

from PIL import Image, ImageDraw
import os

# --- Configuration ---
root_folder = "/content/to_crop"  # The main folder containing subfolders with images
coords = (2158, 1987, 2410, 2136)  # Coordinates for the rectangle (x0, y0, x1, y1)
fill_color = "white"               # Fill color for the rectangle
# --- End Configuration ---

# Filenames to process
target_filenames = {"page_01.png", "page_05.png", "page_09.png", "page_13.png"}

# Check if the root folder exists
if not os.path.isdir(root_folder):
    print(f"Error: Root directory not found at '{root_folder}'")
else:
    print(f"Starting processing in folder: '{root_folder}'")
    processed_count = 0
    error_count = 0

    # Walk through the directory tree
    for dirpath, dirnames, filenames in os.walk(root_folder):
        print(f"Scanning directory: {dirpath}")
        for filename in filenames:
            # Only process the specific filenames (case-sensitive)
            if filename in target_filenames:
                image_path = os.path.join(dirpath, filename)
                print(f"  Processing image: {image_path}...")

                try:
                    with Image.open(image_path) as img:
                        # Convert image mode if needed
                        if img.mode == 'P':
                            img = img.convert('RGBA')
                        elif img.mode == 'L':
                            img = img.convert('RGB')
                        elif img.mode not in ('RGB', 'RGBA'):
                            print(f"    Warning: Image mode '{img.mode}' might not be ideal for drawing. Converting to RGBA.")
                            img = img.convert('RGBA')

                        # Draw the rectangle
                        draw = ImageDraw.Draw(img)
                        draw.rectangle(coords, fill=fill_color, outline=None)

                        # Save changes
                        img.save(image_path, format='PNG')

                    print(f"    Successfully modified and saved: '{image_path}'")
                    processed_count += 1

                except FileNotFoundError:
                    print(f"    Error: File disappeared during processing: '{image_path}'")
                    error_count += 1
                except Exception as e:
                    print(f"    An error occurred while processing '{image_path}': {e}")
                    error_count += 1
            # else:
            #     print(f"  Skipping file: {filename}")  # Optional debugging line

    print("\n--- Processing Complete ---")
    print(f"Total images processed successfully: {processed_count}")
    print(f"Total errors encountered: {error_count}")
# Out:
# Starting processing in folder: '/content/to_crop'
# Scanning directory: /content/to_crop
# Scanning directory: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_05.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_05.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_09.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_09.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_01.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_01.png'
# Scanning directory: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_05.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_05.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_09.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_09.png'
#   Processing image: /content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_01.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_01.png'
# Scanning directory: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_05.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_05.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_09.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_09.png'
#   Processing image: /content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_01.png...
#     Successfully modified and saved: '/content/to_crop/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_01.png'
# Scanning directory: /content/to_crop/Copie CAPES 2025 - Perfection
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_05.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_09.png'
#   Processing image: /content/to_crop/Copie CAPES 2025 - Perfection/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Copie CAPES 2025 - Perfection/page_01.png'
# Scanning directory: /content/to_crop/Copie agreg 2025 - Savoir désirable
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_05.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_09.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Savoir désirable/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Savoir désirable/page_01.png'
# Scanning directory: /content/to_crop/Copie agreg 2025 - Avoir de la chance
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_05.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_05.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_09.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_09.png'
#   Processing image: /content/to_crop/Copie agreg 2025 - Avoir de la chance/page_01.png...
#     Successfully modified and saved: '/content/to_crop/Copie agreg 2025 - Avoir de la chance/page_01.png'
#
# --- Processing Complete ---
# Total images processed successfully: 18
# Total errors encountered: 0

# %%
#@title Troisième encas

from PIL import Image, ImageDraw
import os

# --- Configuration ---
root_folder = "/content/drive/MyDrive/clean"  # The main folder containing subfolders with images
coords = (2144, 2682, 2408, 2846)  # Coordinates for the rectangle (x0, y0, x1, y1)
fill_color = "white"               # Fill color for the rectangle
# --- End Configuration ---

# Filenames to process
target_filenames = {"page_02.png", "page_06.png", "page_10.png", "page_14.png"}

# Check if the root folder exists
if not os.path.isdir(root_folder):
    print(f"Error: Root directory not found at '{root_folder}'")
else:
    print(f"Starting processing in folder: '{root_folder}'")
    processed_count = 0
    error_count = 0

    # Walk through the directory tree
    for dirpath, dirnames, filenames in os.walk(root_folder):
        print(f"Scanning directory: {dirpath}")
        for filename in filenames:
            # Only process the specific filenames (case-sensitive)
            if filename in target_filenames:
                image_path = os.path.join(dirpath, filename)
                print(f"  Processing image: {image_path}...")

                try:
                    with Image.open(image_path) as img:
                        # Convert image mode if needed
                        if img.mode == 'P':
                            img = img.convert('RGBA')
                        elif img.mode == 'L':
                            img = img.convert('RGB')
                        elif img.mode not in ('RGB', 'RGBA'):
                            print(f"    Warning: Image mode '{img.mode}' might not be ideal for drawing. Converting to RGBA.")
                            img = img.convert('RGBA')

                        # Draw the rectangle
                        draw = ImageDraw.Draw(img)
                        draw.rectangle(coords, fill=fill_color, outline=None)

                        # Save changes
                        img.save(image_path, format='PNG')

                    print(f"    Successfully modified and saved: '{image_path}'")
                    processed_count += 1

                except FileNotFoundError:
                    print(f"    Error: File disappeared during processing: '{image_path}'")
                    error_count += 1
                except Exception as e:
                    print(f"    An error occurred while processing '{image_path}': {e}")
                    error_count += 1
            # else:
            #     print(f"  Skipping file: {filename}")  # Optional debugging line

    print("\n--- Processing Complete ---")
    print(f"Total images processed successfully: {processed_count}")
    print(f"Total errors encountered: {error_count}")
# Out:
# Starting processing in folder: '/content/drive/MyDrive/clean'
# Scanning directory: /content/drive/MyDrive/clean
# Scanning directory: /content/drive/MyDrive/clean/Copie agreg 2025 - Savoir désirable
#   Processing image: /content/drive/MyDrive/clean/Copie agreg 2025 - Savoir désirable/page_02.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie agreg 2025 - Savoir désirable/page_02.png'
#   Processing image: /content/drive/MyDrive/clean/Copie agreg 2025 - Savoir désirable/page_06.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie agreg 2025 - Savoir désirable/page_06.png'
#   Processing image: /content/drive/MyDrive/clean/Copie agreg 2025 - Savoir désirable/page_10.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie agreg 2025 - Savoir désirable/page_10.png'
# Scanning directory: /content/drive/MyDrive/clean/Copie CAPES 2025 - Perfection
#   Processing image: /content/drive/MyDrive/clean/Copie CAPES 2025 - Perfection/page_02.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie CAPES 2025 - Perfection/page_02.png'
#   Processing image: /content/drive/MyDrive/clean/Copie CAPES 2025 - Perfection/page_06.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie CAPES 2025 - Perfection/page_06.png'
#   Processing image: /content/drive/MyDrive/clean/Copie CAPES 2025 - Perfection/page_10.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie CAPES 2025 - Perfection/page_10.png'
# Scanning directory: /content/drive/MyDrive/clean/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE
#   Processing image: /content/drive/MyDrive/clean/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_02.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_02.png'
#   Processing image: /content/drive/MyDrive/clean/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_06.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_06.png'
#   Processing image: /content/drive/MyDrive/clean/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_10.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1056399-CAPES EXTERNE PHILOSOPHIE-EPREUVE DISCIPLINAIRE/page_10.png'
# Scanning directory: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE
#   Processing image: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_02.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_02.png'
#   Processing image: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_06.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_06.png'
#   Processing image: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_10.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 2 DE PHILOSOPHIE/page_10.png'
# Scanning directory: /content/drive/MyDrive/clean/Copie agreg 2025 - Avoir de la chance
#   Processing image: /content/drive/MyDrive/clean/Copie agreg 2025 - Avoir de la chance/page_02.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie agreg 2025 - Avoir de la chance/page_02.png'
#   Processing image: /content/drive/MyDrive/clean/Copie agreg 2025 - Avoir de la chance/page_06.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie agreg 2025 - Avoir de la chance/page_06.png'
#   Processing image: /content/drive/MyDrive/clean/Copie agreg 2025 - Avoir de la chance/page_10.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/Copie agreg 2025 - Avoir de la chance/page_10.png'
# Scanning directory: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE
#   Processing image: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_02.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_02.png'
#   Processing image: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_06.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_06.png'
#   Processing image: /content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_10.png...
#     Successfully modified and saved: '/content/drive/MyDrive/clean/N250NAT1091423-AGRÃ_GATION EXTERNE PHILOSOPHIE-COMPOSITION 1 DE PHILOSOPHIE/page_10.png'
#
# --- Processing Complete ---
# Total images processed successfully: 18
# Total errors encountered: 0
