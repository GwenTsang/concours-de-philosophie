# %%
import shutil
import os

src = '/content/drive/MyDrive/OCR de copies automatisé en python'
dst = '/content/folder'

if os.path.exists(dst):
    shutil.rmtree(dst)

shutil.copytree(src, dst)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a6bb456399a7> in <cell line: 0>()
#      78
#      79 if __name__ == "__main__":
# ---> 80     main()
#      81     print("Complete! Original images have been overwritten with cropped versions.")
#
# <ipython-input-1-a6bb456399a7> in main()
#      47     model_files = {
#      48         os.path.splitext(f)[0]: os.path.join(model_dir, f)
# ---> 49         for f in os.listdir(model_dir)
#      50         if f.lower().endswith('.png')
#      51     }
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/model'
